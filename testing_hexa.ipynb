# %%
import ctlearn.hexa.hexaconv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-067f853430a3> in <module>
# ----> 1 import ctlearn.hexa.hexaconv
#
# ~/Desktop/gsoc_ctlear/ctlearn/ctlearn/hexa/hexaconv.py in <module>
#       3 #import torch.nn as nn
#       4 import tensorflow.nn as nn
# ----> 5 import parameter as Parameter
#       6
#       7 # from torch.nn.parameter import Parameter
#
# ModuleNotFoundError: No module named 'parameter'

# %%
print("jbsdhfjvsd")
# Out:
# jbsdhfjvsd
